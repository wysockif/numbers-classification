# %%
import import_ipynb
import basic_create_model_function as al
import tensorflow.keras as keras
import tensorflow as tf 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# importing Jupyter notebook from basic_create_model_function.ipynb
# Trenuję:
# ...
# 313/313 [==============================] - 0s 865us/step - loss: 0.0962 - accuracy: 0.9693
#
# Trenowanie trwało: [2.7056381702423096, 2.484379529953003, 2.2627577781677246] sekund
# Loss dla danych testowych: [0.12195087969303131, 0.09951161593198776, 0.09616893529891968]
# Metryka dla danych testowych: [0.9617000222206116, 0.9679999947547913, 0.9692999720573425]
# Loss dla danych trenowanych - uczących: [0.2546062469482422, 0.10111524164676666, 0.07055281847715378]
# Metryka dla danych trenowanych - uczących: [0.9252166748046875, 0.968916654586792, 0.9774666428565979]
# Trenuję:
# ...
# 313/313 [==============================] - 0s 862us/step - loss: 0.0956 - accuracy: 0.9702
#
# Trenowanie trwało: [2.787931442260742, 2.305093288421631, 2.4009013175964355] sekund
# Loss dla danych testowych: [0.14162898063659668, 0.10751441866159439, 0.09558462351560593]
# ...

# %%
def avarage_create_model_for_different_number_of_layers():
    df = pd.DataFrame(columns=['layer', 'val_loss', 'val_acc', 'loss', 'acc', 'trains_time'])

    index = 0
    
    for i  in range(10):
        index_name = 0
        for number_of_layers in range(10) :
            
            val_loss, val_acc, loss, acc, trains_time, model = al.create_model_with_history_for_all_epochs(layer = number_of_layers)
            
            ls = [number_of_layers,val_loss[-1], val_acc[-1], loss[-1], acc[-1], sum(trains_time)]
            
            df.loc[index] = ls

            index += 1 
            index_name += 1 

    df_mean = df.groupby(by='layer').mean().reset_index()
    return df_mean

# %%
df_mean = avarage_create_model_for_different_number_of_layers()
df_mean
# Out:
# Trenuję:
# ...
# 313/313 [==============================] - 0s 764us/step - loss: 0.2935 - accuracy: 0.9191
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1036 - accuracy: 0.9677
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1015 - accuracy: 0.9689
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.9725
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0985 - accuracy: 0.9714
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1119 - accuracy: 0.9673
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0980 - accuracy: 0.9705
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1374 - accuracy: 0.9640
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1104 - accuracy: 0.9698
# Trenuję:
# ...
