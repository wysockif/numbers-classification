# %%
import import_ipynb
import basic_create_model_function as al
import tensorflow.keras as keras
import tensorflow as tf 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
def average_values_for_different_optimizers():
    df = pd.DataFrame(columns=['optimizer', 'val_loss', 'val_acc', 'loss', 'acc', 'trains_time'])
    optimizers = ['SGD', 'RMSprop', 'Adam', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl']
    
    index = 0
    
    for i  in range(10):
        index_name = 0
        for opt in optimizers :
            
            val_loss, val_acc, loss, acc, trains_time, model = al.create_model_with_history_for_all_epochs(optimizer=opt)
            
            ls = [opt,val_loss[-1], val_acc[-1], loss[-1], acc[-1], sum(trains_time)]
            
            df.loc[index] = ls

            index += 1
            index_name += 1 

    df_mean = df.groupby(by='optimizer').mean().reset_index()
    return df_mean

# %%
df_mean = average_values_for_different_optimizers()
df_mean
# Out:
# Trenuję:
# ...
# 313/313 [==============================] - 0s 910us/step - loss: 0.2940 - accuracy: 0.9173
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0892 - accuracy: 0.9749
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0912 - accuracy: 0.9730
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 2.1777 - accuracy: 0.3483
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5691 - accuracy: 0.8691
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1424 - accuracy: 0.9553
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9735
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 2.3020 - accuracy: 0.1135
# Trenuję:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2876 - accuracy: 0.9205
# Trenuję:
# ...
