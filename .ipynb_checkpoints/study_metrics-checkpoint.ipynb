# %% [markdown]
# # Badanie metryki

# %%
import import_ipynb
import matplotlib.pyplot as plt
import numpy

# %%
import basic_create_model_function as al
# Out:
# importing Jupyter notebook from basic_create_model_function.ipynb
# Trenuję:
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4701 - accuracy: 0.8606
# 313/313 [==============================] - 1s 917us/step - loss: 0.1393 - accuracy: 0.9574
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1052 - accuracy: 0.9675
# 313/313 [==============================] - 0s 881us/step - loss: 0.1020 - accuracy: 0.9680
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0713 - accuracy: 0.9774
# 313/313 [==============================] - 0s 856us/step - loss: 0.0859 - accuracy: 0.9746
#
# Trenowanie trwało: [3.4082603454589844, 2.7682082653045654, 2.7072033882141113] sekund
# Loss dla danych testowych: [0.13932183384895325, 0.10196057707071304, 0.08587978780269623]
# Accuracy dla danych testowych: [0.9574000239372253, 0.9679999947547913, 0.9746000170707703]
# Loss dla danych trenowanych - uczących: [0.26065078377723694, 0.105194091796875, 0.07128266245126724]
# Accuracy dla danych trenowanych - uczących: [0.9227499961853027, 0.9674500226974487, 0.9774166941642761]

# %%
def print_training_time_loss_acc(val_loss, val_acc,loss,acc, training_time):
    print()
    print("Trenowanie trwało: " + str(training_time) + " sekund")
    print("Loss dla danych testowych: " + str(val_loss))
    print("Metryka dla danych testowych: " + str(val_acc))
    print("Loss dla danych trenowanych - uczących: " + str(loss)) 
    print("Metryka dla danych trenowanych - uczących: " + str(acc))

# %%
def plot_loss_and_metric(val_loss, val_acc, loss, acc, metricname='accuracy'):
    plt.plot(acc)
    plt.plot(val_acc)
    plt.title('model' + metricname)
    plt.ylabel(metricname)
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(loss)
    plt.plot(val_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
val_loss, val_acc,loss,acc, training_time, model = al.create_model_with_history_for_all_epochs(verbose = 0)
# Out:
# Trenuję:

# %%
print_training_time_loss_acc(val_loss, val_acc,loss,acc, training_time)
# Out:
# Trenowanie trwało: [2.997227191925049, 2.26116943359375, 2.3171727657318115] sekund
# Loss dla danych testowych: [0.13006573915481567, 0.09596868604421616, 0.09661845862865448]
# Accuracy dla danych testowych: [0.960099995136261, 0.9718000292778015, 0.9695000052452087]
# Loss dla danych trenowanych - uczących: [0.2574225962162018, 0.10247037559747696, 0.07077999413013458]
# Accuracy dla danych trenowanych - uczących: [0.9256166815757751, 0.9691666960716248, 0.9777666926383972]

# %%
plot_loss_and_metric(val_loss, val_acc,loss,acc)

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
s = 0
for i in range (0,500):
    pred = model.predict(x_test[i].reshape(1, 28, 28, 1))
    if pred.argmax() != y_test[i]:
        print(i, end=" ")
        s = s + 1
print(s)
# Out:
# 8 61 115 151 241 247 259 274 320 321 340 391 425 13

# %%
image_index = 115
plt.imshow(x_test[image_index].reshape(28, 28),cmap='Greys')
pred = model.predict(x_test[image_index].reshape(1, 28, 28, 1))
print(y_test[image_index])
print(pred.argmax())
# Out:
# 4
# 9

# %%
print("binary_accuracy")
val_loss, val_acc,loss,acc, training_time, model = al.create_model_with_history_for_all_epochs(verbose = 0, metrics='binary_accuracy')
print(acc[len(acc)-1])
# Out:
# binary_accuracy
# Trenuję:
# 0.10010664910078049

# %%
print("sparse_categorical_crossentropy")
val_loss, val_acc,loss,acc, training_time, model = al.create_model_with_history_for_all_epochs(verbose = 0, metrics='sparse_categorical_crossentropy')
print(acc[len(acc)-1])
# Out:
# sparse_categorical_crossentropy
# Trenuję:
# 0.07483862340450287

# %%
print("mean_squared_error")
val_loss, val_acc,loss,acc, training_time, model = al.create_model_with_history_for_all_epochs(verbose = 0, metrics='mean_squared_error')
print(acc[len(acc)-1])
# Out:
# mean_squared_error
# Trenuję:
# 27.390575408935547
